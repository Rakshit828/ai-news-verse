# %%
import feedparser

tech_crunch = "https://techcrunch.com/feed/"
mit_ai = "https://news.mit.edu/rss/topic/artificial-intelligence2"
openai = "https://openai.com/news/rss.xml"

anthropic_news = "https://raw.githubusercontent.com/Olshansk/rss-feeds/main/feeds/feed_anthropic_news.xml"
anthropic_eng = "https://raw.githubusercontent.com/Olshansk/rss-feeds/main/feeds/feed_anthropic_engineering.xml"


google_news_keword_search = "https://news.google.com/rss/search?q=artificial-intelligence"
hacker_noon = "https://hackernoon.com/feed"

microsoft = 'https://news.microsoft.com/source/feed'

# %%
def _entry_image(entry) -> str:
    if hasattr(entry, "media_content") and entry.media_content:
        for m in entry.media_content:
            if m.get("url"):
                return m["url"]

    if hasattr(entry, "media_thumbnail") and entry.media_thumbnail:
        for m in entry.media_thumbnail:
            if m.get("url"):
                return m["url"]

    if hasattr(entry, "links"):
        for ln in entry.links:
            if ln.get("type", "").startswith("image"):
                return ln.get("href", "")

    summary = getattr(entry, "summary", "") or getattr(entry, "description", "")
    m = re.search(r'<img[^>]+src="([^"]+)"', summary or "")
    if m:
        return m.group(1)

    return ""

# %%
tech_crunch = "https://techcrunch.com/feed/"
mit_ai = "https://news.mit.edu/rss/topic/artificial-intelligence2"
openai = "https://openai.com/news/rss.xml"

anthropic_news = "https://raw.githubusercontent.com/Olshansk/rss-feeds/main/feeds/feed_anthropic_news.xml"
anthropic_eng = "https://raw.githubusercontent.com/Olshansk/rss-feeds/main/feeds/feed_anthropic_engineering.xml"


hacker_noon = "https://hackernoon.com/feed"

microsoft = 'https://news.microsoft.com/source/feed'

# %%
from pydantic import BaseModel, ConfigDict
import time

class OpenAIRssEntry(BaseModel):
    id: str 
    title: str
    summary: str
    link: str 
    idislink: bool = True
    published_parsed: time.struct_time

    model_config = ConfigDict(arbitrary_types_allowed=True)

class AnthropicRssEntry(BaseModel):
    id: str 
    title: str
    summary: str
    link: str 
    idislink: bool = True
    published_parsed: time.struct_time

    model_config = ConfigDict(arbitrary_types_allowed=True)

class HackerNoonRssEntry(BaseModel):
    id: str
    title: str 
    author: str 
    link: str 
    published_parsed: time.struct_time

    idislink: bool = True

    model_config = ConfigDict(arbitrary_types_allowed=True)


class GoogleRssEntry(BaseModel):
    id: str 
    title: str 
    link: str 
    published_parsed: str
    idislink: bool = False


class MitAiRssEntry(BaseModel):
    id: str 
    title: str 
    summary: str 
    link: str 
    published_parsed: time.struct_time
    featured_image: str 
    idislink: bool = True
    
    
    model_config = ConfigDict(arbitrary_types_allowed=True)

# %%
entries = feedparser.parse(google_news_keword_search).entries
entries = [entry for entry in entries if "techcrunch" in entry.source["title"].lower()]
entries
# Out:
# []

# %%
feedparser.parse("https://blog.google/innovation-and-ai/technology/ai/rss/").entries[7]
# Out:
# {'title': 'New ways to create personalized images in the Gemini app',
#  'title_detail': {'type': 'text/plain',
#   'language': 'en-us',
#   'base': 'https://blog.google/innovation-and-ai/technology/ai/rss/',
#   'value': 'New ways to create personalized images in the Gemini app'},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://blog.google/innovation-and-ai/products/gemini-app/personal-intelligence-nano-banana/'}],
#  'link': 'https://blog.google/innovation-and-ai/products/gemini-app/personal-intelligence-nano-banana/',
#  'media_content': [{'height': '540',
#    'medium': 'image',
#    'url': 'https://storage.googleapis.com/gweb-uniblog-publish-prod/images/Blog_post_header.max-600x600.format-webp.webp',
#    'width': '540'}],
#  'summary': 'Example images made with Personal Intelligence',
#  'summary_detail': {'type': 'text/html',
#   'language': 'en-us',
#   'base': 'https://blog.google/innovation-and-ai/technology/ai/rss/',
#   'value': 'Nano Banana 2 now uses your personal context and Google Photos to create images that reflect your unique life.'},
#  'content': [{'type': 'text/plain',
#    'language': 'en-us',
#    'base': 'https://blog.google/innovation-and-ai/technology/ai/rss/',
#    'value': '<img src="https://storage.googleapis.com/gweb-uniblog-publish-prod/images/Blog_post_header.max-600x600.format-webp.webp">Nano Banana 2 now uses your personal context and Google Photos to create images that reflect your unique life.'}],
#  'published': 'Thu, 16 Apr 2026 16:00:00 +0000',
#  'published_parsed': time.struct_time(tm_year=2026, tm_mon=4, tm_mday=16, tm_hour=16, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=106, tm_isdst=0),
#  'id': 'https://blog.google/innovation-and-ai/products/gemini-app/personal-intelligence-nano-banana/',
#  'guidislink': False,
#  'tags': [{'term': 'Gemini App', 'scheme': None, 'label': None},
#   {'term': 'Google One', 'scheme': None, 'label': None},
#   {'term': 'Photos', 'scheme': None, 'label': None},
#   {'term': 'AI', 'scheme': None, 'label': None}],
#  'type': 'article',
#  'site_name': 'Google',
#  'href': 'https://blog.google/innovation-and-ai/products/gemini-app/personal-intelligence-nano-banana/',
#  'og': '',
#  'authors': [{'name': 'Animish Sivaramakrishnan'}, {'name': 'David Sharon'}],
#  'author_detail': {'name': 'David Sharon'},
#  'department': 'Gemini Apps',
#  'company': '',
#  'author': 'David Sharon'}

# %%
feedparser.parse("https://rss.arxiv.org/rss/cs.AI").entries[17]
# Out:
# {'title': 'Agentic World Modeling: Foundations, Capabilities, Laws, and Beyond',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://rss.arxiv.org/rss/cs.AI',
#   'value': 'Agentic World Modeling: Foundations, Capabilities, Laws, and Beyond'},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://arxiv.org/abs/2604.22748'}],
#  'link': 'https://arxiv.org/abs/2604.22748',
#  'summary': 'arXiv:2604.22748v1 Announce Type: new \nAbstract: As AI systems move from generating text to accomplishing goals through sustained interaction, the ability to model environment dynamics becomes a central bottleneck. Agents that manipulate objects, navigate software, coordinate with others, or design experiments require predictive environment models, yet the term world model carries different meanings across research communities. We introduce a "levels x laws" taxonomy organized along two axes. The first defines three capability levels: L1 Predictor, which learns one-step local transition operators; L2 Simulator, which composes them into multi-step, action-conditioned rollouts that respect domain laws; and L3 Evolver, which autonomously revises its own model when predictions fail against new evidence. The second identifies four governing-law regimes: physical, digital, social, and scientific. These regimes determine what constraints a world model must satisfy and where it is most likely to fail. Using this framework, we synthesize over 400 works and summarize more than 100 representative systems spanning model-based reinforcement learning, video generation, web and GUI agents, multi-agent social simulation, and AI-driven scientific discovery. We analyze methods, failure modes, and evaluation practices across level-regime pairs, propose decision-centric evaluation principles and a minimal reproducible evaluation package, and outline architectural guidance, open problems, and governance challenges. The resulting roadmap connects previously isolated communities and charts a path from passive next-step prediction toward world models that can simulate, and ultimately reshape, the environments in which agents operate.',
#  'summary_detail': {'type': 'text/html',
#   'language': None,
#   'base': 'https://rss.arxiv.org/rss/cs.AI',
#   'value': 'arXiv:2604.22748v1 Announce Type: new \nAbstract: As AI systems move from generating text to accomplishing goals through sustained interaction, the ability to model environment dynamics becomes a central bottleneck. Agents that manipulate objects, navigate software, coordinate with others, or design experiments require predictive environment models, yet the term world model carries different meanings across research communities. We introduce a "levels x laws" taxonomy organized along two axes. The first defines three capability levels: L1 Predictor, which learns one-step local transition operators; L2 Simulator, which composes them into multi-step, action-conditioned rollouts that respect domain laws; and L3 Evolver, which autonomously revises its own model when predictions fail against new evidence. The second identifies four governing-law regimes: physical, digital, social, and scientific. These regimes determine what constraints a world model must satisfy and where it is most likely to fail. Using this framework, we synthesize over 400 works and summarize more than 100 representative systems spanning model-based reinforcement learning, video generation, web and GUI agents, multi-agent social simulation, and AI-driven scientific discovery. We analyze methods, failure modes, and evaluation practices across level-regime pairs, propose decision-centric evaluation principles and a minimal reproducible evaluation package, and outline architectural guidance, open problems, and governance challenges. The resulting roadmap connects previously isolated communities and charts a path from passive next-step prediction toward world models that can simulate, and ultimately reshape, the environments in which agents operate.'},
#  'id': 'oai:arXiv.org:2604.22748v1',
#  'guidislink': False,
#  'tags': [{'term': 'cs.AI', 'scheme': None, 'label': None}],
#  'published': 'Mon, 27 Apr 2026 00:00:00 -0400',
#  'published_parsed': time.struct_time(tm_year=2026, tm_mon=4, tm_mday=27, tm_hour=4, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=117, tm_isdst=0),
#  'arxiv_announce_type': 'new',
#  'rights': 'http://arxiv.org/licenses/nonexclusive-distrib/1.0/',
#  'rights_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://rss.arxiv.org/rss/cs.AI',
#   'value': 'http://arxiv.org/licenses/nonexclusive-distrib/1.0/'},
#  'authors': [{'name': 'Meng Chu, Xuan Billy Zhang, Kevin Qinghong Lin, Lingdong Kong, Jize Zhang, Teng Tu, Weijian Ma, Ziqi Huang, Senqiao Yang, Wei Huang, Yeying Jin, Zhefan Rao, Jinhui Ye, Xinyu Lin, Xichen Zhang, Qisheng Hu, Shuai Yang, Leyang Shen, Wei Chow, Yifei Dong, Fengyi Wu, Quanyu Long, Bin Xia, Shaozuo Yu, Mingkang Zhu, Wenhu Zhang, Jiehui Huang, Haokun Gui, Haoxuan Che, Long Chen, Qifeng Chen, Wenxuan Zhang, Wenya Wang, Xiaojuan Qi, Yang Deng, Yanwei Li, Mike Zheng Shou, Zhi-Qi Cheng, See-Kiong Ng, Ziwei Liu, Philip Torr, Jiaya Jia'}],
#  'author': 'Meng Chu, Xuan Billy Zhang, Kevin Qinghong Lin, Lingdong Kong, Jize Zhang, Teng Tu, Weijian Ma, Ziqi Huang, Senqiao Yang, Wei Huang, Yeying Jin, Zhefan Rao, Jinhui Ye, Xinyu Lin, Xichen Zhang, Qisheng Hu, Shuai Yang, Leyang Shen, Wei Chow, Yifei Dong, Fengyi Wu, Quanyu Long, Bin Xia, Shaozuo Yu, Mingkang Zhu, Wenhu Zhang, Jiehui Huang, Haokun Gui, Haoxuan Che, Long Chen, Qifeng Chen, Wenxuan Zhang, Wenya Wang, Xiaojuan Qi, Yang Deng, Yanwei Li, Mike Zheng Shou, Zhi-Qi Cheng, See-Kiong Ng, Ziwei Liu, Philip Torr, Jiaya Jia',
#  'author_detail': {'name': 'Meng Chu, Xuan Billy Zhang, Kevin Qinghong Lin, Lingdong Kong, Jize Zhang, Teng Tu, Weijian Ma, Ziqi Huang, Senqiao Yang, Wei Huang, Yeying Jin, Zhefan Rao, Jinhui Ye, Xinyu Lin, Xichen Zhang, Qisheng Hu, Shuai Yang, Leyang Shen, Wei Chow, Yifei Dong, Fengyi Wu, Quanyu Long, Bin Xia, Shaozuo Yu, Mingkang Zhu, Wenhu Zhang, Jiehui Huang, Haokun Gui, Haoxuan Che, Long Chen, Qifeng Chen, Wenxuan Zhang, Wenya Wang, Xiaojuan Qi, Yang Deng, Yanwei Li, Mike Zheng Shou, Zhi-Qi Cheng, See-Kiong Ng, Ziwei Liu, Philip Torr, Jiaya Jia'}}
