# %%
import feedparser

tech_crunch = "https://techcrunch.com/feed/"
mit_ai = "https://news.mit.edu/rss/topic/artificial-intelligence2"
openai = "https://openai.com/news/rss.xml"

anthropic_news = "https://raw.githubusercontent.com/Olshansk/rss-feeds/main/feeds/feed_anthropic_news.xml"
anthropic_eng = "https://raw.githubusercontent.com/Olshansk/rss-feeds/main/feeds/feed_anthropic_engineering.xml"


google_news_keword_search = "https://news.google.com/rss/search?q=ai-coding"
hacker_noon = "https://hackernoon.com/feed"

microsoft = 'https://news.microsoft.com/source/feed'

# %%
def _entry_image(entry) -> str:
    if hasattr(entry, "media_content") and entry.media_content:
        for m in entry.media_content:
            if m.get("url"):
                return m["url"]

    if hasattr(entry, "media_thumbnail") and entry.media_thumbnail:
        for m in entry.media_thumbnail:
            if m.get("url"):
                return m["url"]

    if hasattr(entry, "links"):
        for ln in entry.links:
            if ln.get("type", "").startswith("image"):
                return ln.get("href", "")

    summary = getattr(entry, "summary", "") or getattr(entry, "description", "")
    m = re.search(r'<img[^>]+src="([^"]+)"', summary or "")
    if m:
        return m.group(1)

    return ""

# %%
tech_crunch = "https://techcrunch.com/feed/"
mit_ai = "https://news.mit.edu/rss/topic/artificial-intelligence2"
openai = "https://openai.com/news/rss.xml"

anthropic_news = "https://raw.githubusercontent.com/Olshansk/rss-feeds/main/feeds/feed_anthropic_news.xml"
anthropic_eng = "https://raw.githubusercontent.com/Olshansk/rss-feeds/main/feeds/feed_anthropic_engineering.xml"


google_news_keword_search = "https://news.google.com/rss/search?q=ai-coding"
hacker_noon = "https://hackernoon.com/feed"

microsoft = 'https://news.microsoft.com/source/feed'

# %%
from pydantic import BaseModel, ConfigDict
import time

class OpenAIRssEntry(BaseModel):
    id: str 
    title: str
    summary: str
    link: str 
    idislink: bool = True
    published_parsed: time.struct_time

    model_config = ConfigDict(arbitrary_types_allowed=True)

class AnthropicRssEntry(BaseModel):
    id: str 
    title: str
    summary: str
    link: str 
    idislink: bool = True
    published_parsed: time.struct_time

    model_config = ConfigDict(arbitrary_types_allowed=True)

class HackerNoonRssEntry(BaseModel):
    id: str
    title: str 
    author: str 
    link: str 
    published_parsed: time.struct_time

    idislink: bool = True

    model_config = ConfigDict(arbitrary_types_allowed=True)


class GoogleRssEntry(BaseModel):
    id: str 
    title: str 
    link: str 
    published_parsed: str
    idislink: bool = False


class MitAiRssEntry(BaseModel):
    id: str 
    title: str 
    summary: str 
    link: str 
    published_parsed: time.struct_time
    featured_image: str 
    idislink: bool = True
    
    
    model_config = ConfigDict(arbitrary_types_allowed=True)

# %%
feedparser.parse(google_news_keword_search).entries[0]
# Out:
# {'title': 'AI Coding Firm Cognition in Funding Talks at $25 Billion Value - Bloomberg',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://news.google.com/rss/search?q=ai-coding&hl=en-US&gl=US&ceid=US:en',
#   'value': 'AI Coding Firm Cognition in Funding Talks at $25 Billion Value - Bloomberg'},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://news.google.?oc=5'}],
#  'link': 'https://news.google.?oc=5',
#  'id': 'CBMisgFBVV95cUxNbVBSUjgxekxSRmVhVnNjSEhYdzItNlBjRUk3YnlOV1k2cjNWMWhCNEtLeFgtUjVvVFFBcFM0RE9Wdk43WnJMRkZFd1VhcThiVDdzUG1vcGVLMGxTSFV6WGV0ZTF2WWFVNXV1dVo2a2pucXJnVnNqLUxPY21TVUxVQjNXel9kckNEMGdzdG41S3dOSHE5WjcwSGprYTEwTlc0dm1GNUZQaWhwSG42Zlc4QTVn',
#  'guidislink': False,
#  'published': 'Thu, 23 Apr 2026 23:54:08 GMT',
#  'published_parsed': time.struct_time(tm_year=2026, tm_mon=4, tm_mday=23, tm_hour=23, tm_min=54, tm_sec=8, tm_wday=3, tm_yday=113, tm_isdst=0),
#  'summary': '<a href="https://news.google.?oc=5" target="_blank">AI Coding Firm Cognition in Funding Talks at $25 Billion Value</a>&nbsp;&nbsp;<font color="#6f6f6f">Bloomberg</font>',
#  'summary_detail': {'type': 'text/html',
#   'language': None,
#   'base': 'https://news.google.com/rss/search?q=ai-coding&hl=en-US&gl=US&ceid=US:en',
#   'value': '<a href="https://news.google.?oc=5" target="_blank">AI Coding Firm Cognition in Funding Talks at $25 Billion Value</a>&nbsp;&nbsp;<font color="#6f6f6f">Bloomberg</font>'},
#  'source': {'href': 'https://www.bloomberg.com', 'title': 'Bloomberg'}}
