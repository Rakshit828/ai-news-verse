# %%
import feedparser

tech_crunch = "https://techcrunch.com/feed/"
mit_ai = "https://news.mit.edu/rss/topic/artificial-intelligence2"
openai = "https://openai.com/news/rss.xml"

anthropic_news = "https://raw.githubusercontent.com/Olshansk/rss-feeds/main/feeds/feed_anthropic_news.xml"
anthropic_eng = "https://raw.githubusercontent.com/Olshansk/rss-feeds/main/feeds/feed_anthropic_engineering.xml"


google_news_keword_search = "https://news.google.com/rss/search?q=ai-coding"
hacker_noon = "https://hackernoon.com/feed"

microsoft = 'https://news.microsoft.com/source/feed'

# %%
feed = feedparser.parse(microsoft)
for entry in feed.entries:
    print(entry.title, entry.link)
    pass
# Out:
# Singtel Singapore CEO uses Microsoft 365 Copilot to unlock ideas – and land big fish https://news.microsoft.com/source/asia/features/singtel-singapore-ceo-uses-microsoft-365-copilot-to-unlock-ideas-and-land-big-fish/
# How Levi Strauss & Co. is refashioning its brand with AI https://www.microsoft.com/en-us/worklab/how-levis-is-refashioning-its-timeless-company-with-ai
# AI Dev Days: Level-up your AI skills with Microsoft Reactor at virtual event Dec. 10-11 https://devblogs.microsoft.com/foundry/ai-dev-days-december-2025/
# Cybersecurity strategies to prioritize now https://www.microsoft.com/en-us/security/blog/2025/12/04/cybersecurity-strategies-to-prioritize-now/
# Microsoft Store Awards honors top apps in 2025 https://blogs.windows.com/windowsdeveloper/2025/12/03/announcing-the-microsoft-store-awards-2025-winners/
# With the Excel World Championship underway, I decided to take the M365 Copilot digital challenge. I’m no World Champ… but thanks to Agent Mode, I held my own! https://www.linkedin.com/posts/satyanadella_with-theexcelworld-championship-underway-activity-7402362298297716736-D8hp
# Introducing Mistral Large 3 in Microsoft Foundry: Open and ready for production workloads https://azure.microsoft.com/en-us/blog/introducing-mistral-large-3-in-microsoft-foundry-open-capable-and-ready-for-production-workloads/
# Small businesses work smarter with AI in Microsoft 365 Copilot Business https://www.microsoft.com/en-us/microsoft-365/blog/2025/12/02/microsoft-365-copilot-business-the-future-of-work-for-small-businesses/
# How healthcare leaders can build cyber resilience https://www.microsoft.com/en-us/industry/blog/healthcare/2025/12/03/future-proofing-healthcare-cybersecurity-what-every-leader-should-know/
# More than 70% of the US could benefit from accessible technology https://blogs.microsoft.com/accessibility/forrester-research-2025/
